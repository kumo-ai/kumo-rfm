# %% [markdown]
# <div>
#   <h1>
#     <img src="https://langchain-ai.github.io/langgraph/static/wordmark_dark.svg" style="height: 40px; vertical-align: bottom;" />
#     +
#     <img src="https://kumo-ai.github.io/kumo-sdk/docs/_static/kumo-logo.svg" style="height: 40px; vertical-align: bottom;""/>
#     RFM Insurance agent demo
#   </h1>
# </div>
#
# This notebook demonstrates how to combine **LangGraph** with the **`KumoRFM` MCP server** to implement a insurance policy risk and retention workflow.
#
# The workflow includes:
#
# 1. **Data Ingestion & Graph Materialization**
#    Load S3 Parquet files into a `KumoRFM` graph, validate schemas, and summarize the resulting graph.
#
# 2. **Policy expiration prediction**
#    Compute churn probabilities for the selected users using predictive queries via `KumoRFM`, highlighting high-risk policies.
#
# 3. **Policy bundling recommendation**
#    Predict which policies at-risk users are most likely interested in, leveraging predictive queries and table lookups.
#
# 4. **Re-Engagement Email Drafting**
#    Automatically draft personalized, persuasive emails including recommended policy bundles and optional discount codes to encourage policy retention and upsell.
#
# This demo illustrates a simple **ReAct agent orchestration** for data engineering, analytics, and policy retention/upsell using LangGraph and MCP tools.
#
# ## Running this notebook
# 1. Create a new environment with `uv` or `pip`
# 2. Install required packages:
# ```
# # Install required libraries
# pip install langchain-core>=0.1.0
# pip install langgraph>=0.0.40
# pip install langchain-mcp-adapters>=0.1.0
# pip install langchain-anthropic>=0.1.0
# pip install kumo-rfm-mcp>=0.1.0
# pip install s3fs>=2025.09.0
# pip install fsspec>=2025.09.0
# pip install jupyter
# ```
# 3. (Optional) Obtain the Kumo API key at [kumorfm.ai](https://kumorfm.ai/api-keys) and set it as an environment variable `export KUMO_API_KEY=<your-api-key>`
# 4. Run the notebook via `jupyter notebook`

# %%
# Install required libraries
# !pip install langchain-core>=0.1.0
# !pip install langgraph>=0.0.40
# !pip install langchain-mcp-adapters>=0.1.0
# !pip install langchain-anthropic>=0.1.0
# !pip install kumo-rfm-mcp>=0.1.0
# !pip install s3fs>=2025.09.0
# !pip install fsspec>=2025.09.0
# Out:
# zsh:1: 0.1.0 not found
# zsh:1: 0.0.40 not found
# zsh:1: 0.1.0 not found
# zsh:1: 0.1.0 not found
# zsh:1: 0.1.0 not found
# zsh:1: 2025.09.0 not found
# zsh:1: 2025.09.0 not found

# %%
# Import required libraries
import asyncio
import os
import json
from typing import TypedDict, Annotated, List
from langchain_core.messages import HumanMessage, SystemMessage, BaseMessage, AIMessage, ToolMessage
from langgraph.graph import StateGraph, START, END, MessagesState
from langgraph.graph.message import add_messages
from langgraph.prebuilt import create_react_agent, ToolNode, tools_condition
from langchain_mcp_adapters.client import MultiServerMCPClient
from langchain_mcp_adapters.tools import load_mcp_tools  # Add this import
from langchain_anthropic import ChatAnthropic

import pandas as pd
from datetime import datetime, timedelta

import kumoai.experimental.rfm as rfm

print("✅ Libraries imported successfully")
# Out:
# ✅ Libraries imported successfully

# %% [markdown]
# ## Set API Keys
# To run this example notebook you will need both a KumoRFM and an Anthropic API key. You can generate the keys by visiting [kumorfm.ai](https://kumorfm.ai/api-keys) and [console.anthropic.com](https://console.anthropic.com/settings/keys) respectively. Make sure to update the values in the cell below!

# %%
# API KEYS
if not os.environ.get("KUMO_API_KEY"):
    rfm.authenticate()

# or for manual setup:
# os.environ['KUMO_API_KEY'] = "<KUMO_API_KEY>"

import getpass

os.environ["ANTHROPIC_API_KEY"] = getpass.getpass("Enter your Anthropic API key: ")

# %% [markdown]
# ## Setup KumoRFM MCP config
#
# LangGraph itself doesn't provide out-of-the-box support for MCP servers, instead it uses it's own tool definitions - see [documentation](https://python.langchain.com/docs/concepts/tools/). But the LangGraph team does provide a helpful toolset to transform MCPs into LangGraph tool calls `langchain-mcp-adapters` ([github](https://github.com/langchain-ai/langchain-mcp-adapters)).
#
# We can take a MCP server configuration and pass it to the `MultiServerMCPClient` class which we can use as a context manager to obtain all the tool calls we need from our server, and it is really as simple as that!
#
# ```{python}
# from langchain_mcp_adapters.tools import load_mcp_tools
#
# client = MultiServerMCPClient(mcp_servers)
# async with client.session("math") as session:
#     tools = await load_mcp_tools(session)
# ```
#
# We define the config for `kumo-rfm-mcp` below.

# %%
# MCP Server Configuration
mcp_servers = {
    "kumo-rfm": {
        "command": "python3",
        "args": ["-m", "kumo_rfm_mcp.server"],
        "env": {
            "KUMO_API_KEY": os.getenv("KUMO_API_KEY"),
        },
        "transport": "stdio",
    },
}

# %% [markdown]
# ## Data config and agent prompt
# Now to the subject of data, we will be using a multi-table dataset which includes insurance customers, policies, claims, agents, and more. We have made the dataset publicly available at: `s3://kumo-sdk-public/rfm-datasets/insurance/`. We provide this as part of the prompt to the agent.
#
# Let us first identify the customers who have expiring policies in the next 30 days:

# %%
DATA_DIR = "s3://kumo-sdk-public/rfm-datasets/insurance"
TEST_DATE = datetime(day=3, month=9, year=2025)

# %%
policies_df = pd.read_csv(f"{DATA_DIR}/policies.csv")
policies_df['expiration_date'] = pd.to_datetime(policies_df['expiration_date'])

DAYS = 30 # Day limit till expiration
days_from_now = TEST_DATE + timedelta(days=30)

# Filter for policies expiring within the next 30 days, not canceled, and status not 'Canceled'
expiring_policies_df = policies_df[
    (policies_df['expiration_date'].notna()) &
    (policies_df['expiration_date'].dt.date >= datetime.now().date()) &
    (policies_df['expiration_date'].dt.date <= days_from_now.date()) &
    ((policies_df['canceled_flag'].isna()) | (policies_df['canceled_flag'] == False)) &
    (policies_df['status'] != 'Canceled')
]

CUSTOMER_IDs = expiring_policies_df['customer_id'].unique().tolist()

print(f"Customer IDs with policies expiring within the next 30 days of {TEST_DATE}:")
print(CUSTOMER_IDs)
# Out:
# Customer IDs with policies expiring within the next 30 days of 2025-09-03 00:00:00:
# [13, 402, 14, 329, 375, 239, 493, 319]

# %% [markdown]
# You can find the agent prompt below, feel free to modify it to get a feel for how the models respond to different instructions. In its current form it executes a complex workflow, including inspecting the tables, defining the graph, running several predictions and finally offering up customized emails with insurance bundling options.

# %%
# Environment Variables
PROMPT = f"""You are an Insurance Churn Prevention Agent. You will be provided a data path and list of file names and a set of customer IDs with policies expiring in the next 30 days. Perform this multi-step workflow:

## STEP 1: Setup and Authentication
1. Start by authenticating with the KumoRFM system using `kumo-rfm:authenticate` tool
2. Find all table files in the data directory using `kumo-rfm:find_table_files` 
3. Inspect all tables using `kumo-rfm:inspect_table_files` to understand the data structure

## STEP 2: Graph Design and Setup
4. Use your domain knowledge to determine optimal graph structure:
   - Identify primary keys and time columns for each table
   - Determine appropriate semantic types for each column
   - Map foreign key relationships between tables
5. Explain your chosen graph structure and reasoning
6. Initialize the graph using `kumo-rfm:update_graph_metadata` to:
   - Add all tables with correct primary keys and time columns
   - Set appropriate semantic types for each column
   - Create foreign key-primary key links between tables
7. Materialize the graph using `kumo-rfm:materialize_graph`

## STEP 3: Renewal Prediction Analysis
8. Predict likelihood of each customer renewing their policy in next 60 days using PQL query:
   ```
   PREDICT COUNT(policies.*, 0, 60, days) > 0 
   FOR customers.customer_id IN (customer_list) 
   WHERE COUNT(policies.*, -365, 0, days) > 0
   ```
9. Categorize customers by churn risk:
   - HIGH RISK: < 30% renewal probability
   - MEDIUM RISK: 30-70% renewal probability  
   - LOW RISK: > 70% renewal probability
10. Summarize renewal prediction results and provide strategic recommendations

## STEP 4: Cross-Selling Analysis
11. For ALL customers (not just those likely to renew), predict which insurance products they're most interested in using:
    ```
    PREDICT LIST_DISTINCT(policies.product_id, 0, 60, days) RANK TOP 5 
    FOR customers.customer_id IN (customer_list)
    ```
12. Look up product names using `kumo-rfm:lookup_table_rows` on the products table
13. Analyze cross-selling opportunities and identify top recommended products per customer

## STEP 5: Personalized Email Generation
14. Generate personalized retention emails for each customer that include:
    - Professional, concise tone (no emojis or overly casual language)
    - Acknowledgment of their expiring policy
    - Renewal discount offer (15-25% off current policy)
    - Bundle discount offer for their current + most recommended new product
    - Clear call-to-action with contact information
    - Sense of urgency but not pushy
15. Customize each email based on:
    - Customer's churn risk level (adjust discount percentage)
    - Their top recommended product for bundling
    - Professional insurance industry language

## STEP 6: Strategic Summary
16. Provide executive summary with:
    - Overall churn risk assessment
    - Revenue impact analysis
    - Recommended immediate actions
    - Success metrics to track

## Data Parameters:
Data Path: {DATA_DIR}
File Names: agents.csv, claim_reports.csv, claims.csv, customers.csv, pets.csv, policies.csv, products.csv, properties.csv, vehicles.csv
Customer IDs: {CUSTOMER_IDs}

## Expected Insurance Domain Knowledge:
- Policies table connects customers to their insurance policies
- Claims table tracks insurance claims made against policies
- Products represent different insurance types (auto, home, renters, etc.)
- Agents are insurance sales representatives
- Properties, vehicles, pets are assets covered by specific policy types
- Time columns are critical for preventing data leakage in predictions
- Foreign keys typically follow pattern: policy_id links to policies, customer_id links to customers, etc.

## Key Success Criteria:
- Graph must be properly structured with correct relationships
- Predictions must use appropriate temporal windows
- Emails must be professional and personalized
- Analysis must provide actionable business insights
- All steps must be executed in sequence with proper error handling
"""

# %% [markdown]
# ## Setting up the main agentic loop
# The `async def main()` function orchestrates an AI insurance agent that combines LangGraph for agent management with MCP (Model Context Protocol) for tool integration. It creates a ReAct agent powered by Claude 3.5 Sonnet that can use real external tools through a persistent MCP session.
#
# ### Key workflow:
# The setup initializes Claude as the language model, establishes a persistent connection to MCP servers via `MultiServerMCPClient` client, and dynamically loads available tools. The persistent session is crucial - it maintains state across tool calls so the agent can build on previous work rather than starting fresh each time.
#
# ### LangGraph streaming and parsing:
# Instead of waiting for a final result, `agent.astream()` provides real-time updates as the agent works. LangGraph streams back chunks containing different node types:
# * `"agent"` nodes: The AI's reasoning and planning process
# * `"tools"` nodes: Actual tool executions with both the tool name and results
#
# This streaming approach lets you watch the agent's decision-making in real-time. The `recursion_limit: 50` prevents infinite loops while allowing complex multi-step problem solving.
#
# The async context manager ensures clean resource management, automatically closing the MCP session when complete. Error handling provides detailed feedback if anything goes wrong during execution.

# %%
async def main():
    """Main execution function using persistent MCP session."""
    
    print("🚀 Starting Insurance Agent Workflow with LangGraph + MCP")
    print("=" * 60)
    
    try:
        # Initialize the chat model
        model = ChatAnthropic(
            model="claude-3-7-sonnet-20250219",
            api_key=os.getenv("ANTHROPIC_API_KEY")
        )
        
        # Setup MCP client with persistent session
        client = MultiServerMCPClient(mcp_servers)
        
        print("🔌 Establishing persistent MCP session...")
        
        # Use persistent session to maintain state across tool calls
        async with client.session("kumo-rfm") as session:
            print("✅ MCP session established")
            
            # Load tools from the persistent session  
            tools = await load_mcp_tools(session)
            print(f"🛠️  Loaded {len(tools)} tools from MCP server")
            
            # Create the ReAct agent with MCP tools
            agent = create_react_agent(
                model, 
                tools,
            )
            
            # Execute the agent with streaming
            print("\n🤖 Agent is starting work...")
            print("=" * 40)
            
            # Stream the agent's work in real-time
            async for chunk in agent.astream(
                {"messages": [HumanMessage(content=PROMPT)]},
                {"recursion_limit": 50},
            ):

                # Parse chunk content based on type
                for node, content in chunk.items():
                    if node == "agent":
                        print("🤖 Agent:")
                        for message in content["messages"]:
                            if hasattr(message, 'content'):
                                print(f"   AI: {message.content}")
                    elif node == "tools":
                        print("🛠️  Tools:")
                        for message in content["messages"]:
                            if hasattr(message, 'content'):
                                print(f"   Tool Result: {message.content}")
                            if hasattr(message, 'name'):
                                print(f"   Tool Name: {message.name}")
                print("-" * 40)
        
        print("\n✅ Workflow completed! MCP session closed.")
                
    except Exception as e:
        print(f"❌ Agent execution failed: {e}")
        import traceback
        traceback.print_exc()

# %% [markdown]
# ## Running the agent
# We can run the main function in a IPython notebook with a simple `await` - run and see for yourself!

# %%
await main()
# Out:
# 🚀 Starting Insurance Agent Workflow with LangGraph + MCP
# ============================================================
# 🔌 Establishing persistent MCP session...
# ✅ MCP session established
# 🛠️  Loaded 11 tools from MCP server
#
# 🤖 Agent is starting work...
# ========================================
# 🤖 Agent:
#    AI: [{'text': "# Insurance Churn Prevention Analysis\n\nI'll help you execute the multi-step workflow to analyze and prevent customer churn for the insurance company. Let's proceed step-by-step:\n\n## STEP 1: Setup and Authentication\n\nLet me start by authenticating with the KumoRFM system:", 'type': 'text'}, {'id': 'toolu_01S48Kr6AgPHDq2rbACtx2s6', 'input': {}, 'name': 'authenticate', 'type': 'tool_use'}]
# ----------------------------------------
# 🛠️  Tools:
#    Tool Result: KumoRFM session successfully authenticated
#    Tool Name: authenticate
# ----------------------------------------
# 🤖 Agent:
#    AI: [{'text': "Now, let's find all table files in the specified S3 directory:", 'type': 'text'}, {'id': 'toolu_01QCgdMyERuPESCGNAFTjm3g', 'input': {'path': 's3://kumo-sdk-public/rfm-datasets/insurance', 'recursive': False}, 'name': 'find_table_files', 'type': 'tool_use'}]
# ----------------------------------------
# 🛠️  Tools:
#    Tool Result: Error: ToolException("Directory 's3:/kumo-sdk-public/rfm-datasets/insurance' does not exist")
#  Please fix your mistakes.
#    Tool Name: find_table_files
# ----------------------------------------
# 🤖 Agent:
#    AI: [{'text': 'I apologize for the error. Let me correct the path format:', 'type': 'text'}, {'id': 'toolu_011uXfhu2EUTmc9ewo4dm3t9', 'input': {'paths': ['s3://kumo-sdk-public/rfm-datasets/insurance/agents.csv', 's3://kumo-sdk-public/rfm-datasets/insurance/claim_reports.csv', 's3://kumo-sdk-public/rfm-datasets/insurance/claims.csv', 's3://kumo-sdk-public/rfm-datasets/insurance/customers.csv', 's3://kumo-sdk-public/rfm-datasets/insurance/pets.csv', 's3://kumo-sdk-public/rfm-datasets/insurance/policies.csv', 's3://kumo-sdk-public/rfm-datasets/insurance/products.csv', 's3://kumo-sdk-public/rfm-datasets/insurance/properties.csv', 's3://kumo-sdk-public/rfm-datasets/insurance/vehicles.csv']}, 'name': 'inspect_table_files', 'type': 'tool_use'}]
# ----------------------------------------
# 🛠️  Tools:
#    Tool Result: {"s3://kumo-sdk-public/rfm-datasets/insurance/agents.csv":{"rows":[{"agent_id":0,"hire_date":"2014-08-20","region":"East","name":"Agent_0"},{"agent_id":1,"hire_date":"2011-08-18","region":"South","name":"Agent_1"},{"agent_id":2,"hire_date":"2022-03-18","region":"Midwest","name":"Agent_2"},{"agent_id":3,"hire_date":"2014-12-30","region":"East","name":"Agent_3"},{"agent_id":4,"hire_date":"2010-01-13","region":"Midwest","name":"Agent_4"},{"agent_id":5,"hire_date":"2011-06-15","region":"East","name":"Agent_5"},{"agent_id":6,"hire_date":"2021-06-22","region":"West","name":"Agent_6"},{"agent_id":7,"hire_date":"2024-12-19","region":"South","name":"Agent_7"},{"agent_id":8,"hire_date":"2020-05-28","region":"South","name":"Agent_8"},{"agent_id":9,"hire_date":"2011-12-09","region":"Midwest","name":"Agent_9"},{"agent_id":10,"hire_date":"2011-02-05","region":"Midwest","name":"Agent_10"},{"agent_id":11,"hire_date":"2006-05-26","region":"South","name":"Agent_11"},{"agent_id":12,"hire_date":"2006-02-26","region":"East","name":"Agent_12"},{"agent_id":13,"hire_date":"2015-07-14","region":"Midwest","name":"Agent_13"},{"agent_id":14,"hire_date":"2023-02-13","region":"Midwest","name":"Agent_14"},{"agent_id":15,"hire_date":"2023-03-26","region":"Midwest","name":"Agent_15"},{"agent_id":16,"hire_date":"2011-03-03","region":"East","name":"Agent_16"},{"agent_id":17,"hire_date":"2016-06-04","region":"East","name":"Agent_17"},{"agent_id":18,"hire_date":"2025-03-29","region":"East","name":"Agent_18"},{"agent_id":19,"hire_date":"2019-08-03","region":"South","name":"Agent_19"}]},"s3://kumo-sdk-public/rfm-datasets/insurance/claim_reports.csv":{"rows":[{"report_id":0,"claim_id":0,"report_date":"2014-02-12","report_type":"police_report","summary":"Report police_report for claim 0"},{"report_id":1,"claim_id":0,"report_date":"2014-03-09","report_type":"adjuster_note","summary":"Report adjuster_note for claim 0"},{"report_id":2,"claim_id":0,"report_date":"2014-03-02","report_type":"police_report","summary":"Report police_report for claim 0"},{"report_id":3,"claim_id":0,"report_date":"2014-03-08","report_type":"police_report","summary":"Report police_report for claim 0"},{"report_id":4,"claim_id":0,"report_date":"2014-02-24","report_type":"police_report","summary":"Report police_report for claim 0"},{"report_id":5,"claim_id":1,"report_date":"2017-08-04","report_type":"police_report","summary":"Report police_report for claim 1"},{"report_id":6,"claim_id":1,"report_date":"2017-07-24","report_type":"customer_statement","summary":"Report customer_statement for claim 1"},{"report_id":7,"claim_id":2,"report_date":"2015-10-01","report_type":"police_report","summary":"Report police_report for claim 2"},{"report_id":8,"claim_id":2,"report_date":"2015-11-06","report_type":"adjuster_note","summary":"Report adjuster_note for claim 2"},{"report_id":9,"claim_id":2,"report_date":"2015-10-24","report_type":"adjuster_note","summary":"Report adjuster_note for claim 2"},{"report_id":10,"claim_id":2,"report_date":"2015-10-29","report_type":"police_report","summary":"Report police_report for claim 2"},{"report_id":11,"claim_id":3,"report_date":"2017-10-08","report_type":"adjuster_note","summary":"Report adjuster_note for claim 3"},{"report_id":12,"claim_id":3,"report_date":"2017-10-09","report_type":"adjuster_note","summary":"Report adjuster_note for claim 3"},{"report_id":13,"claim_id":3,"report_date":"2017-09-05","report_type":"adjuster_note","summary":"Report adjuster_note for claim 3"},{"report_id":14,"claim_id":4,"report_date":"2010-08-18","report_type":"adjuster_note","summary":"Report adjuster_note for claim 4"},{"report_id":15,"claim_id":4,"report_date":"2010-08-13","report_type":"customer_statement","summary":"Report customer_statement for claim 4"},{"report_id":16,"claim_id":4,"report_date":"2010-08-02","report_type":"police_report","summary":"Report police_report for claim 4"},{"report_id":17,"claim_id":4,"report_date":"2010-08-12","report_type":"police_repo ...
#    Tool Name: inspect_table_files
# ----------------------------------------
# 🤖 Agent:
#    AI: [{'text': "Now that I have inspected all the tables, I understand the data structure and can proceed to design the graph.\n\n## STEP 2: Graph Design and Setup\n\nBased on the data inspection, I'll determine the optimal graph structure by identifying primary keys, time columns, semantic types, and relationships between tables.\n\n### Graph Design Explanation:\n\n1. **Core Entities and Relationships**:\n   - `customers` table is the central entity connecting to policies (one-to-many)\n   - `policies` table connects to various asset tables (vehicles, properties, pets) and claims\n   - `agents` manage policies (one-to-many)\n   - `products` define the type of insurance (auto, home, etc.)\n   - `claims` are filed against policies (one-to-many)\n   - `claim_reports` document the claims (one-to-many)\n\n2. **Primary Keys**:\n   - `customer_id` in customers table\n   - `policy_id` in policies table\n   - `agent_id` in agents table\n   - `product_id` in products table\n   - `claim_id` in claims table\n   - `report_id` in claim_reports table\n   - Each asset table has its own ID field\n\n3. **Time Columns**:\n   - `signup_date` for customers\n   - `effective_date` for policies\n   - `hire_date` for agents\n   - `incident_date` for claims\n   - `report_date` for claim_reports\n\n4. **Semantic Types**:\n   - IDs: customer_id, policy_id, agent_id, product_id, claim_id, report_id\n   - Timestamps: dates like signup_date, effective_date, hire_date\n   - Categoricals: status, product_name, claim_status, etc.\n   - Numericals: premium amounts, deductibles, age, year built, etc.\n   - Text: descriptions, names, etc.\n\nNow, let's initialize the graph with the correct structure:", 'type': 'text'}, {'id': 'toolu_01H7ZrqGbHeAybYAZ5uvhXBq', 'input': {}, 'name': 'update_graph_metadata', 'type': 'tool_use'}]
# ----------------------------------------
# 🛠️  Tools:
#    Tool Result: Error: ToolException("Input validation error: 'update' is a required property")
#  Please fix your mistakes.
#    Tool Name: update_graph_metadata
# ----------------------------------------
# 🤖 Agent:
#    AI: [{'text': 'Let me provide the complete graph metadata structure:', 'type': 'text'}, {'id': 'toolu_01Tpn1z2TKNNeq8r4qmtvHhh', 'input': {'update': {'tables_to_add': [{'name': 'customers', 'path': 's3://kumo-sdk-public/rfm-datasets/insurance/customers.csv', 'primary_key': 'customer_id', 'time_column': 'signup_date'}, {'name': 'policies', 'path': 's3://kumo-sdk-public/rfm-datasets/insurance/policies.csv', 'primary_key': 'policy_id', 'time_column': 'effective_date'}, {'name': 'agents', 'path': 's3://kumo-sdk-public/rfm-datasets/insurance/agents.csv', 'primary_key': 'agent_id', 'time_column': 'hire_date'}, {'name': 'products', 'path': 's3://kumo-sdk-public/rfm-datasets/insurance/products.csv', 'primary_key': 'product_id', 'time_column': None}, {'name': 'claims', 'path': 's3://kumo-sdk-public/rfm-datasets/insurance/claims.csv', 'primary_key': 'claim_id', 'time_column': 'incident_date'}, {'name': 'claim_reports', 'path': 's3://kumo-sdk-public/rfm-datasets/insurance/claim_reports.csv', 'primary_key': 'report_id', 'time_column': 'report_date'}, {'name': 'vehicles', 'path': 's3://kumo-sdk-public/rfm-datasets/insurance/vehicles.csv', 'primary_key': 'vehicle_id', 'time_column': None}, {'name': 'properties', 'path': 's3://kumo-sdk-public/rfm-datasets/insurance/properties.csv', 'primary_key': 'property_id', 'time_column': None}, {'name': 'pets', 'path': 's3://kumo-sdk-public/rfm-datasets/insurance/pets.csv', 'primary_key': 'pet_id', 'time_column': None}], 'links_to_add': [{'source_table': 'policies', 'foreign_key': 'customer_id', 'destination_table': 'customers'}, {'source_table': 'policies', 'foreign_key': 'agent_id', 'destination_table': 'agents'}, {'source_table': 'policies', 'foreign_key': 'product_id', 'destination_table': 'products'}, {'source_table': 'claims', 'foreign_key': 'policy_id', 'destination_table': 'policies'}, {'source_table': 'claim_reports', 'foreign_key': 'claim_id', 'destination_table': 'claims'}, {'source_table': 'vehicles', 'foreign_key': 'policy_id', 'destination_table': 'policies'}, {'source_table': 'properties', 'foreign_key': 'policy_id', 'destination_table': 'policies'}, {'source_table': 'pets', 'foreign_key': 'policy_id', 'destination_table': 'policies'}]}}, 'name': 'update_graph_metadata', 'type': 'tool_use'}]
# ----------------------------------------
# 🛠️  Tools:
#    Tool Result: {"graph":{"tables":[{"path":"s3://kumo-sdk-public/rfm-datasets/insurance/customers.csv","name":"customers","num_rows":500,"dtypes":{"customer_id":"int","first_name":"string","last_name":"string","email":"string","birth_year":"int","signup_date":"string","state":"string","customer_tenure_years":"float"},"stypes":{"customer_id":"ID","first_name":"text","last_name":"text","email":"text","birth_year":"numerical","signup_date":"timestamp","state":"categorical","customer_tenure_years":"numerical"},"primary_key":"customer_id","time_column":"signup_date"},{"path":"s3://kumo-sdk-public/rfm-datasets/insurance/policies.csv","name":"policies","num_rows":2000,"dtypes":{"policy_id":"int","customer_id":"int","agent_id":"int","product_id":"int","effective_date":"string","term_years":"int","expiration_date":"string","canceled_flag":"bool","status":"string","annual_premium_usd":"float","deductible_usd":"int","life_face_amount_usd":"float","life_insured_age":"float"},"stypes":{"policy_id":"ID","customer_id":"ID","agent_id":"ID","product_id":"ID","effective_date":"timestamp","term_years":"categorical","expiration_date":"timestamp","canceled_flag":"categorical","status":"categorical","annual_premium_usd":"numerical","deductible_usd":"numerical","life_face_amount_usd":"numerical","life_insured_age":"numerical"},"primary_key":"policy_id","time_column":"effective_date"},{"path":"s3://kumo-sdk-public/rfm-datasets/insurance/agents.csv","name":"agents","num_rows":40,"dtypes":{"agent_id":"int","hire_date":"string","region":"string","name":"string"},"stypes":{"agent_id":"ID","hire_date":"timestamp","region":"categorical","name":"text"},"primary_key":"agent_id","time_column":"hire_date"},{"path":"s3://kumo-sdk-public/rfm-datasets/insurance/products.csv","name":"products","num_rows":8,"dtypes":{"product_id":"int","product_name":"string"},"stypes":{"product_id":"ID","product_name":"categorical"},"primary_key":"product_id","time_column":null},{"path":"s3://kumo-sdk-public/rfm-datasets/insurance/claims.csv","name":"claims","num_rows":393,"dtypes":{"claim_id":"int","policy_id":"int","incident_date":"string","claim_paid_usd":"float","claim_reserved_usd":"float","claim_status":"string"},"stypes":{"claim_id":"ID","policy_id":"ID","incident_date":"timestamp","claim_paid_usd":"numerical","claim_reserved_usd":"numerical","claim_status":"categorical"},"primary_key":"claim_id","time_column":"incident_date"},{"path":"s3://kumo-sdk-public/rfm-datasets/insurance/claim_reports.csv","name":"claim_reports","num_rows":1181,"dtypes":{"report_id":"int","claim_id":"int","report_date":"string","report_type":"string","summary":"string"},"stypes":{"report_id":"ID","claim_id":"ID","report_date":"timestamp","report_type":"categorical","summary":"text"},"primary_key":"report_id","time_column":"report_date"},{"path":"s3://kumo-sdk-public/rfm-datasets/insurance/vehicles.csv","name":"vehicles","num_rows":851,"dtypes":{"policy_id":"int","product_id":"int","vehicle_id":"int","year":"int","make":"string","model":"string","vin":"string"},"stypes":{"policy_id":"ID","product_id":"ID","vehicle_id":"ID","year":"categorical","make":"categorical","model":"categorical","vin":"text"},"primary_key":"vehicle_id","time_column":null},{"path":"s3://kumo-sdk-public/rfm-datasets/insurance/properties.csv","name":"properties","num_rows":1142,"dtypes":{"policy_id":"int","product_id":"int","property_id":"int","year_built":"int","property_type":"string","estimated_value_usd":"int","postal_code":"string"},"stypes":{"policy_id":"ID","product_id":"ID","property_id":"ID","year_built":"numerical","property_type":"categorical","estimated_value_usd":"numerical","postal_code":"ID"},"primary_key":"property_id","time_column":null},{"path":"s3://kumo-sdk-public/rfm-datasets/insurance/pets.csv","name":"pets","num_rows":6,"dtypes":{"policy_id":"int","pet_id":"int","pet_type":"string","breed":"string","age_years":"int","weight_kg":"float"},"stypes":{"policy_id":"ID","pet_id":"ID","pet_type":"categorical","bre ...
#    Tool Name: update_graph_metadata
# ----------------------------------------
# 🤖 Agent:
#    AI: [{'text': "Now that the graph metadata has been set up, let's materialize the graph:", 'type': 'text'}, {'id': 'toolu_01BKPzQaqerTKzNc4pYECE6F', 'input': {}, 'name': 'materialize_graph', 'type': 'tool_use'}]
# ----------------------------------------
# 🛠️  Tools:
#    Tool Result: {"num_nodes":6121,"num_edges":19146,"time_ranges":{"customers":"2005-09-14 00:00:00 - 2025-07-12 00:00:00","policies":"2005-09-07 00:00:00 - 2025-08-28 00:00:00","agents":"2006-02-26 00:00:00 - 2025-06-09 00:00:00","claims":"2006-03-24 00:00:00 - 2025-08-28 00:00:00","claim_reports":"2006-03-27 00:00:00 - 2025-10-04 00:00:00"}}
#    Tool Name: materialize_graph
# ----------------------------------------
# 🤖 Agent:
#    AI: [{'text': "Let's also visualize the graph structure using the Mermaid diagram:", 'type': 'text'}, {'id': 'toolu_01PXoxmFTixnp3tmvAyGqNnW', 'input': {'show_columns': True}, 'name': 'get_mermaid', 'type': 'tool_use'}]
# ----------------------------------------
# 🛠️  Tools:
#    Tool Result: erDiagram
#     customers {
#         ID customer_id PK
#         timestamp signup_date
#         text first_name
#         text last_name
#         text email
#         numerical birth_year
#         categorical state
#         numerical customer_tenure_years
#     }
#     policies {
#         ID policy_id PK
#         ID customer_id FK
#         ID agent_id FK
#         ID product_id FK
#         timestamp effective_date
#         categorical term_years
#         timestamp expiration_date
#         categorical canceled_flag
#         categorical status
#         numerical annual_premium_usd
#         numerical deductible_usd
#         numerical life_face_amount_usd
#         numerical life_insured_age
#     }
#     agents {
#         ID agent_id PK
#         timestamp hire_date
#         categorical region
#         text name
#     }
#     products {
#         ID product_id PK
#         categorical product_name
#     }
#     claims {
#         ID claim_id PK
#         ID policy_id FK
#         timestamp incident_date
#         numerical claim_paid_usd
#         numerical claim_reserved_usd
#         categorical claim_status
#     }
#     claim_reports {
#         ID report_id PK
#         ID claim_id FK
#         timestamp report_date
#         categorical report_type
#         text summary
#     }
#     vehicles {
#         ID vehicle_id PK
#         ID policy_id FK
#         ID product_id
#         categorical year
#         categorical make
#         categorical model
#         text vin
#     }
#     properties {
#         ID property_id PK
#         ID policy_id FK
#         ID product_id
#         numerical year_built
#         categorical property_type
#         numerical estimated_value_usd
#         ID postal_code
#     }
#     pets {
#         ID pet_id PK
#         ID policy_id FK
#         categorical pet_type
#         categorical breed
#         numerical age_years
#         categorical weight_kg
#     }
#
#     customers o|--o{ policies : customer_id
#     agents o|--o{ policies : agent_id
#     products o|--o{ policies : product_id
#     policies o|--o{ claims : policy_id
#     claims o|--o{ claim_reports : claim_id
#     policies o|--o{ vehicles : policy_id
#     policies o|--o{ properties : policy_id
#     policies o|--o{ pets : policy_id
#    Tool Name: get_mermaid
# ----------------------------------------
# 🤖 Agent:
#    AI: [{'text': "## STEP 3: Renewal Prediction Analysis\n\nLet's predict the likelihood of renewal for the specified customer IDs using the PQL query:", 'type': 'text'}, {'id': 'toolu_01FLikRNhrnWAH3HAgnvMXqZ', 'input': {'query': 'PREDICT COUNT(policies.*, 0, 60, days) > 0 FOR customers.customer_id IN (13, 402, 14, 329, 375, 239, 493, 319) WHERE COUNT(policies.*, -365, 0, days) > 0', 'run_mode': 'normal'}, 'name': 'predict', 'type': 'tool_use'}]
# ----------------------------------------
# 🛠️  Tools:
#    Tool Result: {"predictions":[{"ENTITY":13,"ANCHOR_TIMESTAMP":1759536000000,"TARGET_PRED":false,"False_PROB":0.9667099118,"True_PROB":0.0332900807},{"ENTITY":402,"ANCHOR_TIMESTAMP":1759536000000,"TARGET_PRED":false,"False_PROB":0.9627417922,"True_PROB":0.0372582003},{"ENTITY":14,"ANCHOR_TIMESTAMP":1759536000000,"TARGET_PRED":false,"False_PROB":0.9672409296,"True_PROB":0.0327590853},{"ENTITY":329,"ANCHOR_TIMESTAMP":1759536000000,"TARGET_PRED":false,"False_PROB":0.9608992338,"True_PROB":0.0391007811},{"ENTITY":375,"ANCHOR_TIMESTAMP":1759536000000,"TARGET_PRED":false,"False_PROB":0.9632624388,"True_PROB":0.0367375538},{"ENTITY":239,"ANCHOR_TIMESTAMP":1759536000000,"TARGET_PRED":false,"False_PROB":0.9611917138,"True_PROB":0.0388082974},{"ENTITY":493,"ANCHOR_TIMESTAMP":1759536000000,"TARGET_PRED":false,"False_PROB":0.9610664845,"True_PROB":0.0389335155},{"ENTITY":319,"ANCHOR_TIMESTAMP":1759536000000,"TARGET_PRED":false,"False_PROB":0.9635330439,"True_PROB":0.0364669636}],"logs":["Identified temporal binary classification task","Derived anchor time 2025-10-04","Collected 1,656 in-context examples with 3.38% positive cases","Generated context of size 0.26MB","Duration: 1.812917s"]}
#    Tool Name: predict
# ----------------------------------------
# 🤖 Agent:
#    AI: [{'text': "Now let's categorize the customers by churn risk based on the renewal probabilities:\n\n### Churn Risk Categorization:\n- **HIGH RISK (< 30% renewal probability)**: All customers (13, 402, 14, 329, 375, 239, 493, 319)\n- **MEDIUM RISK (30-70% renewal probability)**: None\n- **LOW RISK (> 70% renewal probability)**: None\n\n### Renewal Prediction Summary:\n\nAll of the identified customers are at **HIGH RISK** of not renewing their policies, with renewal probabilities ranging from just 3.3% to 3.9%. This is a concerning pattern that requires immediate attention. The model shows that these customers have a very high likelihood of churning.\n\nKey observations:\n- Customer #329 has the highest renewal probability at 3.91%, which is still extremely low\n- Customer #13 has the lowest renewal probability at 3.33%\n- The average renewal probability across all customers is approximately 3.67%\n\n## STEP 4: Cross-Selling Analysis\n\nLet's predict which insurance products each customer might be interested in:", 'type': 'text'}, {'id': 'toolu_01QmyYz3HQRVDYdUj5P4Vqjv', 'input': {'query': 'PREDICT LIST_DISTINCT(policies.product_id, 0, 60, days) RANK TOP 5 FOR customers.customer_id IN (13, 402, 14, 329, 375, 239, 493, 319)', 'run_mode': 'normal'}, 'name': 'predict', 'type': 'tool_use'}]
# ----------------------------------------
# 🛠️  Tools:
#    Tool Result: {"predictions":[{"ENTITY":13,"ANCHOR_TIMESTAMP":1759536000000,"CLASS":1,"SCORE":0.2744954526},{"ENTITY":13,"ANCHOR_TIMESTAMP":1759536000000,"CLASS":2,"SCORE":0.2735853791},{"ENTITY":13,"ANCHOR_TIMESTAMP":1759536000000,"CLASS":3,"SCORE":0.1554777771},{"ENTITY":13,"ANCHOR_TIMESTAMP":1759536000000,"CLASS":4,"SCORE":0.1554777771},{"ENTITY":13,"ANCHOR_TIMESTAMP":1759536000000,"CLASS":5,"SCORE":0.1554777771},{"ENTITY":402,"ANCHOR_TIMESTAMP":1759536000000,"CLASS":2,"SCORE":0.3462104797},{"ENTITY":402,"ANCHOR_TIMESTAMP":1759536000000,"CLASS":3,"SCORE":0.2463531196},{"ENTITY":402,"ANCHOR_TIMESTAMP":1759536000000,"CLASS":1,"SCORE":0.2061952651},{"ENTITY":402,"ANCHOR_TIMESTAMP":1759536000000,"CLASS":4,"SCORE":0.1554777771},{"ENTITY":402,"ANCHOR_TIMESTAMP":1759536000000,"CLASS":5,"SCORE":0.1554777771},{"ENTITY":14,"ANCHOR_TIMESTAMP":1759536000000,"CLASS":1,"SCORE":0.2701422572},{"ENTITY":14,"ANCHOR_TIMESTAMP":1759536000000,"CLASS":3,"SCORE":0.2054777741},{"ENTITY":14,"ANCHOR_TIMESTAMP":1759536000000,"CLASS":2,"SCORE":0.1554777771},{"ENTITY":14,"ANCHOR_TIMESTAMP":1759536000000,"CLASS":4,"SCORE":0.1554777771},{"ENTITY":14,"ANCHOR_TIMESTAMP":1759536000000,"CLASS":5,"SCORE":0.1554777771},{"ENTITY":329,"ANCHOR_TIMESTAMP":1759536000000,"CLASS":2,"SCORE":0.2755440176},{"ENTITY":329,"ANCHOR_TIMESTAMP":1759536000000,"CLASS":3,"SCORE":0.2233601958},{"ENTITY":329,"ANCHOR_TIMESTAMP":1759536000000,"CLASS":1,"SCORE":0.1554777771},{"ENTITY":329,"ANCHOR_TIMESTAMP":1759536000000,"CLASS":4,"SCORE":0.1554777771},{"ENTITY":329,"ANCHOR_TIMESTAMP":1759536000000,"CLASS":5,"SCORE":0.1554777771},{"ENTITY":375,"ANCHOR_TIMESTAMP":1759536000000,"CLASS":2,"SCORE":0.5243923664},{"ENTITY":375,"ANCHOR_TIMESTAMP":1759536000000,"CLASS":1,"SCORE":0.2349612117},{"ENTITY":375,"ANCHOR_TIMESTAMP":1759536000000,"CLASS":3,"SCORE":0.1554777771},{"ENTITY":375,"ANCHOR_TIMESTAMP":1759536000000,"CLASS":4,"SCORE":0.1554777771},{"ENTITY":375,"ANCHOR_TIMESTAMP":1759536000000,"CLASS":5,"SCORE":0.1554777771},{"ENTITY":239,"ANCHOR_TIMESTAMP":1759536000000,"CLASS":2,"SCORE":0.4960938692},{"ENTITY":239,"ANCHOR_TIMESTAMP":1759536000000,"CLASS":1,"SCORE":0.2473244667},{"ENTITY":239,"ANCHOR_TIMESTAMP":1759536000000,"CLASS":3,"SCORE":0.1554777771},{"ENTITY":239,"ANCHOR_TIMESTAMP":1759536000000,"CLASS":4,"SCORE":0.1554777771},{"ENTITY":239,"ANCHOR_TIMESTAMP":1759536000000,"CLASS":5,"SCORE":0.1554777771},{"ENTITY":493,"ANCHOR_TIMESTAMP":1759536000000,"CLASS":2,"SCORE":0.4658735991},{"ENTITY":493,"ANCHOR_TIMESTAMP":1759536000000,"CLASS":1,"SCORE":0.2409633249},{"ENTITY":493,"ANCHOR_TIMESTAMP":1759536000000,"CLASS":3,"SCORE":0.1554777771},{"ENTITY":493,"ANCHOR_TIMESTAMP":1759536000000,"CLASS":4,"SCORE":0.1554777771},{"ENTITY":493,"ANCHOR_TIMESTAMP":1759536000000,"CLASS":5,"SCORE":0.1554777771},{"ENTITY":319,"ANCHOR_TIMESTAMP":1759536000000,"CLASS":2,"SCORE":0.3691088557},{"ENTITY":319,"ANCHOR_TIMESTAMP":1759536000000,"CLASS":1,"SCORE":0.2532613277},{"ENTITY":319,"ANCHOR_TIMESTAMP":1759536000000,"CLASS":3,"SCORE":0.1554777771},{"ENTITY":319,"ANCHOR_TIMESTAMP":1759536000000,"CLASS":4,"SCORE":0.1554777771},{"ENTITY":319,"ANCHOR_TIMESTAMP":1759536000000,"CLASS":5,"SCORE":0.1554777771}],"logs":["Identified temporal link prediction task","Derived anchor time 2025-10-04","Collected 276 in-context examples with 6 unique items","Generated context of size 0.12MB","Duration: 1.226177s"]}
#    Tool Name: predict
# ----------------------------------------
# 🤖 Agent:
#    AI: [{'text': "Let's look up product names to understand what these product_id values represent:", 'type': 'text'}, {'id': 'toolu_01AZzpQN8WCm911kz4QCy1KQ', 'input': {'table_name': 'products', 'ids': [1, 2, 3, 4, 5]}, 'name': 'lookup_table_rows', 'type': 'tool_use'}]
# ----------------------------------------
# 🛠️  Tools:
#    Tool Result: {"rows":[{"product_id":1,"product_name":"auto"},{"product_id":2,"product_name":"home"},{"product_id":3,"product_name":"renters"},{"product_id":4,"product_name":"motorcycle"},{"product_id":5,"product_name":"boat"}]}
#    Tool Name: lookup_table_rows
# ----------------------------------------
# 🤖 Agent:
#    AI: ### Cross-Selling Analysis:
#
# Based on the predictions, here are the top recommended products for each customer:
#
# 1. **Customer #13**:
#    - Top recommendation: Auto insurance (product_id 1, score: 27.4%)
#    - Second recommendation: Home insurance (product_id 2, score: 27.4%)
#    - Other options: Renters, Motorcycle, Boat (all at 15.5%)
#
# 2. **Customer #402**:
#    - Top recommendation: Home insurance (product_id 2, score: 34.6%)
#    - Second recommendation: Renters insurance (product_id 3, score: 24.6%)
#    - Third recommendation: Auto insurance (product_id 1, score: 20.6%)
#
# 3. **Customer #14**:
#    - Top recommendation: Auto insurance (product_id 1, score: 27.0%)
#    - Second recommendation: Renters insurance (product_id 3, score: 20.5%)
#    - Other options: Home, Motorcycle, Boat (all at 15.5%)
#
# 4. **Customer #329**:
#    - Top recommendation: Home insurance (product_id 2, score: 27.6%)
#    - Second recommendation: Renters insurance (product_id 3, score: 22.3%)
#    - Other options: Auto, Motorcycle, Boat (all at 15.5%)
#
# 5. **Customer #375**:
#    - Top recommendation: Home insurance (product_id 2, score: 52.4%) - Strong preference
#    - Second recommendation: Auto insurance (product_id 1, score: 23.5%)
#    - Other options: Renters, Motorcycle, Boat (all at 15.5%)
#
# 6. **Customer #239**:
#    - Top recommendation: Home insurance (product_id 2, score: 49.6%) - Strong preference
#    - Second recommendation: Auto insurance (product_id 1, score: 24.7%)
#    - Other options: Renters, Motorcycle, Boat (all at 15.5%)
#
# 7. **Customer #493**:
#    - Top recommendation: Home insurance (product_id 2, score: 46.6%) - Strong preference
#    - Second recommendation: Auto insurance (product_id 1, score: 24.1%)
#    - Other options: Renters, Motorcycle, Boat (all at 15.5%)
#
# 8. **Customer #319**:
#    - Top recommendation: Home insurance (product_id 2, score: 36.9%)
#    - Second recommendation: Auto insurance (product_id 1, score: 25.3%)
#    - Other options: Renters, Motorcycle, Boat (all at 15.5%)
#
# ### Key Cross-Selling Insights:
# - Home insurance is the most frequently recommended product (top recommendation for 6 out of 8 customers)
# - Auto insurance is the top recommendation for 2 customers and a strong second option for most others
# - Customers #375, #239 and #493 show particularly strong preference for home insurance (>45% scores)
# - Motorcycle and boat insurance have lower recommendation scores and might be niche products for this customer segment
#
# ## STEP 5: Personalized Email Generation
#
# Based on the analysis, I'll now generate personalized emails for each customer, taking into account their churn risk and product recommendations:
#
# ### Customer #13
# ```
# Subject: Important Update: Your Policy Renewal and Special Offer
#
# Dear First_13 Last_13,
#
# We hope this email finds you well. We're reaching out because your insurance policy is set to expire within the next 30 days.
#
# As a valued customer since June 2019, we would like to offer you an exclusive 25% discount on your policy renewal. Our records indicate you might also be interested in enhancing your coverage with our Auto or Home insurance plans, which would qualify you for an additional 10% bundle discount.
#
# To take advantage of these significant savings or discuss any questions about your coverage options, please contact your agent at (800) 555-1234 or reply to this email.
#
# Please note that to ensure continuous coverage, we recommend renewing your policy at least 7 days before the expiration date.
#
# Sincerely,
# The Insurance Team
# ```
#
# ### Customer #402
# ```
# Subject: Your Policy Renewal: Limited-Time Discount Offer
#
# Dear First_402 Last_402,
#
# We wanted to reach out to inform
# ----------------------------------------
#
# ✅ Workflow completed! MCP session closed.

# %% [markdown]
# ## We'd love to hear from you! ❤️
#
# 1. **Found a bug or have a feature request?**
#    Submit issues directly on [GitHub](https://github.com/kumo-ai/kumo-rfm). Your feedback helps us improve RFM for everyone.
#
# 2. **Built something cool with RFM? We'd love to see it!**
#    Share your project on LinkedIn and tag @kumo. We regularly spotlight on our official channels—yours could be next!
#
# <div align="left">
#   <img src="https://kumo-sdk-public.s3.us-west-2.amazonaws.com/rfm-colabs/kumo_ai_logo.jpeg" width="30" />
# </div>
